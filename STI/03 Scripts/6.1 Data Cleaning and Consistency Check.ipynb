# %% [markdown]
# This script contains the following:
# 1.Importing Visualization Libraries and Data
# 2.Data Wrangling and Cleaning

# %%
#1. import libraries
import pandas as pd
import numpy as np
import os

# %%
df = pd.read_csv(r'/Users/joshd/Documents/Personal/CareerFoundry/Data Analytics Immersion/6/STI/02 Data/Original Data/STD Cases.csv', index_col = False)

# %%
df.columns
# Out:
# Index(['Disease', 'Disease Code', 'State', 'Year', 'Gender', 'Age', 'Age Code',
#        'STD Cases', 'Population', 'Rate per 100K'],
#       dtype='object')

# %%
df.shape
# Out:
# (42530, 10)

# %% [markdown]
# #2. Data Wrangling and Cleaning

# %%
df.head(20)
# Out:
#       Disease  Disease Code    State  Year Gender          Age Age Code  \
# 0   Chlamydia           274  Alabama  1996   Male   0-14 years     0-14
# 1   Chlamydia           274  Alabama  1996   Male  15-19 years    15-19
# 2   Chlamydia           274  Alabama  1996   Male  20-24 years    20-24
# 3   Chlamydia           274  Alabama  1996   Male  25-29 years    25-29
# 4   Chlamydia           274  Alabama  1996   Male  30-34 years    30-34
# 5   Chlamydia           274  Alabama  1996   Male  35-39 years    35-39
# 6   Chlamydia           274  Alabama  1996   Male    40+ years      40+
# 7   Chlamydia           274  Alabama  1996   Male      Unknown       99
# 8   Chlamydia           274  Alabama  1997   Male   0-14 years     0-14
# 9   Chlamydia           274  Alabama  1997   Male  15-19 years    15-19
# 10  Chlamydia           274  Alabama  1997   Male  20-24 years    20-24
# 11  Chlamydia           274  Alabama  1997   Male  25-29 years    25-29
# ...

# %%
#find missing values
df.isnull().sum()
# Out:
# Disease             0
# Disease Code        0
# State               0
# Year                0
# Gender              0
# Age                 0
# Age Code            0
# STD Cases           0
# Population       7047
# Rate per 100K    7047
# dtype: int64

# %%
df.dtypes
# Out:
# Disease           object
# Disease Code       int64
# State             object
# Year               int64
# Gender            object
# Age               object
# Age Code          object
# STD Cases          int64
# Population       float64
# Rate per 100K    float64
# dtype: object

# %%
#drop not needed columns
df.drop(['Disease Code','Age Code'], axis=1, inplace=True)

# %%
df.describe()
# Out:
#                Year     STD Cases    Population  Rate per 100K
# count  42530.000000  42530.000000  3.548300e+04   35483.000000
# mean    2005.240607    603.133647  4.389794e+05     325.661860
# std        5.431696   1973.091099  7.605588e+05     697.545461
# min     1996.000000      1.000000  1.293700e+04       0.020000
# 25%     2001.000000      8.000000  9.418100e+04       6.950000
# 50%     2005.000000     59.000000  1.966280e+05      52.890000
# 75%     2010.000000    380.000000  4.322250e+05     302.955000
# max     2014.000000  46885.000000  8.880836e+06    9078.950000

# %%
#check for dups
df_dups = df[df.duplicated()]
df_dups
# Out:
# Empty DataFrame
# Columns: [Disease, State, Year, Gender, Age, STD Cases, Population, Rate per 100K]
# Index: []

# %%
df.shape
# Out:
# (42530, 8)

# %%
#Check for mixed-type columns
for col in df.columns.tolist():
      weird = (df[[col]].applymap(type) != df[[col]].iloc[0].apply(type)).any(axis = 1)
      if len (df[weird]) > 0:
        print (col)
        
# No mixed-type columns either!

# %%
#save dataset as Pickle
df.to_pickle('/Users/joshd/Documents/Personal/CareerFoundry/Data Analytics Immersion/6/STI/02 Data/Prepared Data/STD Cases.pkl')
